# %% [markdown]
# # Flight Data Analysis
#
# This notebook explores the cleaned flight dataset to surface route volume, international traffic patterns, airport activity, and estimated emissions hotspots. The analysis is descriptive and uses summary tables plus a few map visualizations to communicate scale and geography.
#
# **Dataset:** `./clean_data/final_flight_data.csv`

# %% [markdown]
# ## Environment setup
# Install required packages if they are not already available in the runtime.

# %%
# %pip install pandas numpy nbformat
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: nbformat in ./.venv/lib/python3.13/site-packages (5.10.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.13/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.13/site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.13/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in ./.venv/lib/python3.13/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data loading
# Load the cleaned flight dataset once so all downstream analyses share the same source data.

# %%
import pandas as pd

df = pd.read_csv('./clean_data/final_flight_data.csv')

# %% [markdown]
# ## Route volume by airline
# Rank carriers by the number of distinct routes in the dataset. This highlights which airlines have the broadest network coverage.

# %%
route_counts = df['airline_name'].value_counts().rename('routes')
top_50 = route_counts.head(50).to_frame()


display(top_50)
# Out:
#                            routes
# airline_name
# Ryanair                      2484
# Air China                     822
# China Southern Airlines       791
# China Eastern Airlines        668
# easyJet                       623
# American Airlines             511
# Hainan Airlines               498
# Shenzhen Airlines             467
# United Airlines               462
# Iberia Airlines               454
# Wizz Air                      453
# Delta Air Lines               356
# Lufthansa                     341
# Sichuan Airlines              326
# Turkish Airlines              316
# Air France                    298
# Air India Limited             269
# Aeroflot Russian Airlines     261
# Air Canada                    253
# Shandong Airlines             248
# JetBlue Airways               237
# Ural Airlines                 228
# S7 Airlines                   223
# All Nippon Airways            208
# LAN Airlines                  203
# IndiGo Airlines               199
# Saudi Arabian Airlines        188
# Spirit Airlines               185
# AirAsia                       178
# Emirates                      171
# Asiana Airlines               170
# Jet2.com                      158
# Pegasus Airlines              154
# Aer Lingus                    150
# Volaris                       149
# Jetstar Airways               147
# Frontier Airlines             146
# Royal Air Maroc               141
# Juneyao Airlines              136
# Malaysia Airlines             133
# Japan Airlines                132
# British Airways               131
# Etihad Airways                130
# Garuda Indonesia              129
# Air Algerie                   128
# Ethiopian Airlines            126
# Air Arabia                    126
# Lion Mentari Airlines         124
# Aegean Airlines               123
# Vietnam Airlines              122

# %% [markdown]
# ## Top source and destination countries (overall)
# Compare where flights most often originate and terminate, regardless of whether they are domestic or international.

# %%
source_country = df["source_port_country"].value_counts().rename('source_count').head(10)
destination_country = df["destination_port_country"].value_counts().rename('destination_count').head(10)

display(source_country)
display(destination_country)
# Out:
# source_port_country
# China             4060
# United States     1940
# Spain             1015
# United Kingdom     906
# Italy              685
# France             656
# Germany            596
# Russia             592
# India              562
# Japan              410
# Name: source_count, dtype: int64
# destination_port_country
# China             4056
# United States     1938
# Spain             1021
# United Kingdom     912
# Italy              684
# France             655
# Russia             592
# Germany            587
# India              562
# Turkey             411
# Name: destination_count, dtype: int64

# %% [markdown]
# ## International traffic by country
# Focus on flights where the source and destination countries differ to see which countries act as key international origins and destinations.

# %%
international_df = df[df['source_port_country'] != df['destination_port_country']]
source_int = international_df['source_port_country'].value_counts().rename('international_source_count').head(10)
destination_int = international_df['destination_port_country'].value_counts().rename('international_destination_count').head(10)

display(source_int)
display(destination_int)
# Out:
# source_port_country
# United States           859
# United Kingdom          857
# Spain                   790
# China                   658
# Germany                 588
# France                  577
# Italy                   537
# Russia                  377
# United Arab Emirates    347
# Japan                   336
# Name: international_source_count, dtype: int64
# destination_port_country
# United Kingdom          863
# United States           857
# Spain                   796
# China                   654
# Germany                 579
# France                  576
# Italy                   536
# Russia                  377
# United Arab Emirates    346
# Japan                   333
# Name: international_destination_count, dtype: int64

# %% [markdown]
# ## Busiest city pairs

# %%
# count routes by unordered (combined) country pairs (treat A-B same as B-A)
international_df = df[df['source_port_city'] != df['destination_port_city']].copy()
pairs = international_df.apply(lambda r: sorted([r['source_port_city'], r['destination_port_city']]), axis=1)
pairs_df = pairs.apply(pd.Series)
pairs_df.columns = ['city_a', 'city_b']
undirected_counts = (
    pairs_df.groupby(['city_a', 'city_b'])
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
)

display(undirected_counts.head(50))
undirected_counts.to_csv('./clean_data/busiest_city_pairs.csv', index=False)
# Out:
#             city_a          city_b  count
# 975        Bangkok      Chiang Rai     20
# 1030       Bangkok          Phuket     18
# 2814       Chicago           Paris     18
# 7192      Shanghai          Taipei     16
# 6973       Qingdao        Shanghai     16
# 1003       Bangkok    Kuala Lumpur     16
# 6248        Milano        New York     14
# 4473      Hangzhou       Zhengzhou     14
# 5926         Macau        Shanghai     14
# 1151     Barcelona        New York     14
# 4977       Jakarta    Kuala Lumpur     13
# 3602        Dublin          London     13
# 74       Abu Dhabi          Muscat     13
# 6214         Miami           Paris     13
# 5802        London          Warsaw     12
# 7154         Seoul        Shanghai     12
# 3916     Frankfurt          Jeddah     12
# 7438        Urumqi       Zhengzhou     12
# 2136      Budapest          London     12
# 6542       Nanning           Wuhan     12
# 4350       Guiyang       Zhengzhou     12
# 7195      Shanghai         Tianjin     12
# 7165         Seoul           Tokyo     12
# 974        Bangkok      Chiang Mai     12
# 7214      Shanghai          Yantai     12
# 4340       Guiyang        Shanghai     12
# 2353     Cape Town    Johannesburg     12
# 2501      Changcha          Xiamen     12
# 2793       Chicago     Duesseldorf     12
# 7206      Shanghai           Xi'an     11
# 4536        Harbin       Zhengzhou     11
# 5527       Lanzhou          Urumqi     11
# 6855         Perth       Singapore     11
# 3492        Douala         Yaounde     11
# 2737       Chengdu         Qingdao     11
# 5395  Kuala Lumpur          Phuket     10
# 2102     Bucharest          London     10
# 5746        London  Raleigh-durham     10
# 5069         Jinan           Xi'an     10
# 2748       Chengdu         Taiyuan     10
# 2754       Chengdu           Wuhan     10
# 2741       Chengdu        Shanghai     10
# 5742        London          Prague     10
# 5529       Lanzhou           Xi'an     10
# 6659         Ninbo         Qingdao     10
# 6531       Nanjing          Xiamen     10
# 6647        Niamey     Ouagadougou     10
# 2888     Chongqing           Lhasa     10
# 141    Addis Ababa          Jeddah     10
# 1482       Belfast          London     10

# %% [markdown]
# ## Busiest international country pairs
# Identify the most common international country pairs. Treat A–B and B–A as the same pair to capture total two-way demand.

# %%
# count routes by unordered (combined) country pairs (treat A-B same as B-A)
international_df = df[df['source_port_country'] != df['destination_port_country']].copy()
pairs = international_df.apply(lambda r: sorted([r['source_port_country'], r['destination_port_country']]), axis=1)
pairs_df = pairs.apply(pd.Series)
pairs_df.columns = ['country_a', 'country_b']
undirected_counts = (
    pairs_df.groupby(['country_a', 'country_b'])
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
)

display(undirected_counts.head(50))
undirected_counts.to_csv('./clean_data/busiest_international_country_pairs.csv', index=False)
# Out:
#                country_a             country_b  count
# 1376               Spain        United Kingdom    403
# 1155              Mexico         United States    230
# 421                China           South Korea    189
# 402                China                 Japan    189
# 777              Germany                 Spain    173
# 425                China                Taiwan    172
# 981                Italy                 Spain    166
# 719               France        United Kingdom    131
# 1267              Poland        United Kingdom    128
# 708               France                 Spain    126
# 986                Italy        United Kingdom    122
# 396                China             Hong Kong    115
# 1306              Russia            Uzbekistan    105
# 427                China              Thailand    105
# 938              Ireland                 Spain    102
# 902                India  United Arab Emirates    100
# 363               Canada         United States     99
# 753              Germany                 Italy     99
# 821               Greece        United Kingdom     96
# 673               France                 Italy     94
# 788              Germany         United States     91
# 783              Germany                Turkey     89
# 687               France               Morocco     88
# 1001               Japan           South Korea     88
# 720               France         United States     85
# 745              Germany                Greece     85
# 1433      United Kingdom         United States     83
# 911            Indonesia             Singapore     72
# 12               Algeria                France     70
# 228              Belgium                 Spain     69
# 943              Ireland        United Kingdom     69
# 787              Germany        United Kingdom     68
# 987                Italy         United States     66
# 1297              Russia            Tajikistan     65
# 87             Australia           New Zealand     62
# 1278            Portugal        United Kingdom     61
# 907            Indonesia              Malaysia     61
# 1377               Spain         United States     60
# 552   Dominican Republic         United States     59
# 1003               Japan                Taiwan     58
# 975                Italy               Romania     55
# 892                India          Saudi Arabia     54
# 697               France              Portugal     54
# 210              Belgium                 Italy     52
# 1008               Japan         United States     51
# 418                China                Russia     51
# 1192         Netherlands                 Spain     50
# 1121            Malaysia              Thailand     46
# 973                Italy                Poland     46
# 1397         Switzerland         United States     46

# %% [markdown]
# ## Busiest airports (inbound + outbound)
# Combine departures and arrivals to rank airports by total route activity.

# %%
out_routes = df.groupby("source_port_name").size().rename("routes_out")

# Count inbound routes
in_routes = df.groupby("destination_port_name").size().rename("routes_in")

routes_by_airport = (
    pd.concat([out_routes, in_routes], axis=1)
    .fillna(0)
    .astype(int)
)

# Total routes (in + out)
routes_by_airport["total_routes"] = (
    routes_by_airport["routes_out"] + routes_by_airport["routes_in"]
)

rank = routes_by_airport.sort_values("total_routes", ascending=False)

rank
# Out:
#                                              routes_out  routes_in  \
# Beijing Capital International Airport               233        234
# Shanghai Pudong International Airport               228        225
# Singapore Changi Airport                            193        202
# Chengdu Shuangliu International Airport             188        192
# Charles de Gaulle International Airport             184        183
# ...                                                 ...        ...
# San Sebastian Airport                                 1          0
# Nome Airport                                          1          0
# Lubumbashi International Airport                      1          0
# Lubbock Preston Smith International Airport           1          0
# Saarbrücken Airport                                   0          1
#
#                                              total_routes
# Beijing Capital International Airport                 467
# Shanghai Pudong International Airport                 453
# Singapore Changi Airport                              395
# Chengdu Shuangliu International Airport               380
# Charles de Gaulle International Airport               367
# ...                                                   ...
# San Sebastian Airport                                   1
# Nome Airport                                            1
# Lubumbashi International Airport                        1
# Lubbock Preston Smith International Airport             1
# Saarbrücken Airport                                     1
#
# [1370 rows x 3 columns]

# %% [markdown]
# ## Route network snapshot (sampled map)
# Plot a random sample of routes to illustrate the global network shape without rendering every line.

# %%
try:
    import plotly.graph_objects as go
except Exception:
    import sys, subprocess
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'plotly'])
    import plotly.graph_objects as go

sample_df = df.sample(n=min(2000, len(df)), random_state=42)

lons = []
lats = []
for _, row in sample_df.iterrows():
    lons += [row['source_port_longitude'], row['destination_port_longitude'], None]
    lats += [row['source_port_latitude'], row['destination_port_latitude'], None]

fig = go.Figure(
    data=go.Scattergeo(
        lon=lons,
        lat=lats,
        mode='lines',
        line=dict(width=0.6, color='royalblue'),
        opacity=0.5,
    )
)

fig.update_layout(
    title='Sampled Flight Routes (Source → Destination)',
    showlegend=False,
    geo=dict(
        projection_type='natural earth',
        showcountries=True,
        showland=True,
        landcolor='rgb(243, 243, 243)',
        coastlinecolor='rgb(204, 204, 204)',
    ),
)

fig.show()

# %% [markdown]
# ## Highest CO2 routes
# List the routes with the largest total CO2 estimates to flag emissions-heavy legs.

# %%
# Highest CO2 per leg
high_co2 = df.sort_values('co2_total_kg', ascending=False).head(20)
high_co2 = high_co2[[
    'airline_name',
    'plane_name',
    'source_port_name',
    'destination_port_name',
    'distance_km',
    'co2_total_kg',
]]
display(high_co2)
# Out:
#                  airline_name        plane_name  \
# 18539         United Airlines   Airbus A340-600
# 18530         United Airlines   Airbus A340-600
# 15699   South African Airways   Airbus A340-600
# 2994          JetBlue Airways   Airbus A340-600
# 15689   South African Airways   Airbus A340-600
# 2966          JetBlue Airways   Airbus A340-600
# 6366           Etihad Airways   Airbus A340-500
# 6428           Etihad Airways   Airbus A340-500
# 5571          Delta Air Lines   Airbus A340-600
# 13402  China Eastern Airlines   Airbus A340-600
# 13601  China Eastern Airlines   Airbus A340-600
# 5689          Delta Air Lines   Airbus A340-600
# 6370           Etihad Airways   Airbus A340-600
# 6432           Etihad Airways   Airbus A340-600
# 15708   South African Airways   Airbus A340-300
# 3894                Air China   Airbus A340-300
# 5434          Delta Air Lines  Boeing 777-200LR
# 5576          Delta Air Lines  Boeing 777-200LR
# 13608  China Eastern Airlines   Airbus A340-600
# 5598          Delta Air Lines   Airbus A340-600
#
#                                         source_port_name  \
# 18539                     OR Tambo International Airport
# 18530               John F Kennedy International Airport
# 15699                     OR Tambo International Airport
# 2994                      OR Tambo International Airport
# 15689               John F Kennedy International Airport
# 2966                John F Kennedy International Airport
# 6366                     Abu Dhabi International Airport
# 6428   Guarulhos - Governador André Franco Montoro In...
# 5571                John F Kennedy International Airport
# 13402               John F Kennedy International Airport
# 13601              Shanghai Pudong International Airport
# 5689               Shanghai Pudong International Airport
# 6370                     Abu Dhabi International Airport
# 6432             Washington Dulles International Airport
# 15708              Beijing Capital International Airport
# 3894               Beijing Capital International Airport
# 5434    Hartsfield Jackson Atlanta International Airport
# 5576                      OR Tambo International Airport
# 13608              Shanghai Pudong International Airport
# 5598                   Los Angeles International Airport
#
#                                    destination_port_name   distance_km  \
# 18539               John F Kennedy International Airport  12831.326650
# 18530                     OR Tambo International Airport  12831.326650
# 15699               John F Kennedy International Airport  12831.326650
# 2994                John F Kennedy International Airport  12831.326650
# 15689                     OR Tambo International Airport  12831.326650
# 2966                      OR Tambo International Airport  12831.326650
# 6366   Guarulhos - Governador André Franco Montoro In...  12120.963492
# 6428                     Abu Dhabi International Airport  12120.963492
# 5571               Shanghai Pudong International Airport  11873.664607
# 13402              Shanghai Pudong International Airport  11873.664607
# 13601               John F Kennedy International Airport  11873.664607
# 5689                John F Kennedy International Airport  11873.664607
# 6370             Washington Dulles International Airport  11386.790979
# 6432                     Abu Dhabi International Airport  11386.790979
# 15708                     OR Tambo International Airport  11707.971503
# 3894                      OR Tambo International Airport  11707.971503
# 5434                      OR Tambo International Airport  13582.587878
# 5576    Hartsfield Jackson Atlanta International Airport  13582.587878
# 13608                  Los Angeles International Airport  10415.273585
# 5598               Shanghai Pudong International Airport  10415.273585
#
#        co2_total_kg
# 18539   1642.409811
# 18530   1642.409811
# 15699   1642.409811
# 2994    1642.409811
# 15689   1642.409811
# 2966    1642.409811
# 6366    1575.725254
# 6428    1575.725254
# 5571    1519.829070
# 13402   1519.829070
# 13601   1519.829070
# 5689    1519.829070
# 6370    1457.509245
# 6432    1457.509245
# 15708   1440.080495
# 3894    1440.080495
# 5434    1385.423964
# 5576    1385.423964
# 13608   1333.155019
# 5598    1333.155019

# %% [markdown]
# ## Emissions hotspots (aggregated midpoints)
# Aggregate CO2 by route midpoints to highlight geographic clusters of high emissions.

# %%
try:
    import plotly.express as px
except Exception:
    import sys, subprocess
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'plotly'])
    import plotly.express as px

# Aggregate emissions by route midpoint to keep the map readable
routes = df.copy()
routes['mid_lat'] = (routes['source_port_latitude'] + routes['destination_port_latitude']) / 2
routes['mid_lon'] = (routes['source_port_longitude'] + routes['destination_port_longitude']) / 2
agg = (
    routes.groupby(['mid_lat', 'mid_lon'], as_index=False)['co2_total_kg']
    .sum()
    .sort_values('co2_total_kg', ascending=False)
)

# Limit to top points for performance
agg = agg.head(2000)

fig = px.scatter_geo(
    agg,
    lat='mid_lat',
    lon='mid_lon',
    color='co2_total_kg',
    size='co2_total_kg',
    color_continuous_scale='YlOrRd',
    projection='natural earth',
    title='Suspected CO₂ Emissions by Route (Aggregated Midpoints)',
)
fig.update_layout(
    geo=dict(showland=True, landcolor='rgb(243, 243, 243)', showcountries=True),
    legend_title_text='CO₂ (kg)',
)
fig.show()

# %% [markdown]
# ## Top international carriers
# Rank airlines by the number of international routes and show their share of all international routes.

# %%
# Top international flight carriers
intl_counts = df[df['is_international']].groupby('airline_name').size().sort_values(ascending=False)
top_intl = intl_counts.head(20).to_frame(name='international_routes')
top_intl['share_pct'] = (top_intl['international_routes'] / intl_counts.sum() * 100).round(2)
display(top_intl)
# Out:
#                            international_routes  share_pct
# airline_name
# Ryanair                                    2214      16.54
# easyJet                                     557       4.16
# Wizz Air                                    453       3.38
# United Airlines                             372       2.78
# Iberia Airlines                             346       2.59
# Lufthansa                                   319       2.38
# American Airlines                           297       2.22
# Air Canada                                  247       1.85
# Air France                                  239       1.79
# Turkish Airlines                            235       1.76
# China Southern Airlines                     219       1.64
# Delta Air Lines                             211       1.58
# China Eastern Airlines                      187       1.40
# Aeroflot Russian Airlines                   186       1.39
# Air China                                   176       1.32
# Ural Airlines                               171       1.28
# Emirates                                    167       1.25
# Jet2.com                                    158       1.18
# Saudi Arabian Airlines                      157       1.17
# Asiana Airlines                             153       1.14
